# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/enrolment_1.csv')
df
# Out:
#            id  year           course name
# 0     2777729     1               science
# 1     2777730     2               science
# 2     2777765     1                  arts
# 3     2777766     2                  arts
# 4     2777785     1                   mba
# ...       ...   ...                   ...
# 1995  2796805     3  computer application
# 1996  2796812     1               nursing
# 1997  2796813     2               nursing
# 1998  2796814     3               nursing
# 1999  2796815     4               nursing
#
# [2000 rows x 3 columns]

# %%
df['status'] = 'allowed'
info_tech_cond = (df['course name'] == 'information technology') & (df['year'] == 1)
commerce_cond = (df['course name'] == 'commerce') & (df['year'] == 4)
df.loc[info_tech_cond | commerce_cond, 'status'] = 'not allowed'

# %%
stu_cond = df['course name'].value_counts()
leak_stu_course = list(stu_cond[stu_cond < 5].index)
leak_stu_course
# df['status'] = np.where(leak_stu_course, 'not allowed', np.where(info_tech_cond | commerce_cond, 'not allowed', 'allowed'))
# Out:
# ['chemical',
#  'computer engg with specialization in cloud computing.',
#  'electronics & communication engineering',
#  'mech',
#  'mechanical related subjects',
#  'civil engg',
#  'tool & die making',
#  'electronics and instrumentation',
#  'electrical and electronics engineering',
#  'leather design',
#  'pathology',
#  'mechanical engg.',
#  'database',
#  'electronics and communication',
#  'refactoring',
#  'bpt',
#  'korean',
#  'data structure',
#  'physical education',
#  'computer architecture',
#  'fashion communication',
#  'instrumentation engineering',
#  'electrical engg',
#  'electros & communicationnic',
#  'environment',
#  'agriculture',
#  'engg. & tech.',
#  'applied sc.',
#  'information subjects',
#  'gandhian thought',
#  'bcom (general)',
#  'jain darshan',
#  'electronic',
#  'bjmc',
#  'vocational',
#  'btzc',
#  'i.t',
#  'all subjects',
#  'community medicine',
#  'em',
#  'civit',
#  'mobile communication',
#  'diploma',
#  'comp(em)',
# ...
