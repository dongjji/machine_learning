# %% [markdown]
# # <font color=blue> 기계학습과 인공신경망  8장: 분류기 (Logistic Regression)</font>
# ###  Machine Learning and Bioinformatics (MLBI) Lab @ DKU, 2020.07.04 <br>

# %%
import datetime as dt
import math
import numpy as np
import pandas as pd
import sklearn.linear_model as lm
import sklearn.svm as svm
import sklearn.model_selection as mod_sel
import sklearn.metrics as met
from sklearn.manifold import TSNE
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from matplotlib import cm

## Function to draw UMAP plot conveniently
def draw_scatter(pnt_2d, y, Title = None):
    C_map = cm.get_cmap('Spectral', 256)  # 'viridis'
    
    plt.figure(num=None, figsize=(16, 16), dpi=80, facecolor='w', edgecolor='k')

    ## Under the original label
    plt.subplot(2,2,1)
    scatters = []      
    z = y
    y_label = list(set(z))
    nl = len(y_label)-1
    for k, lbl in enumerate(y_label):
        n = y_label[k]
        scatters.append(plt.scatter(pnt_2d[z==n, 0], pnt_2d[z==n, 1], \
                                    color=C_map(k/nl), # marker=markers[k], \
                                    label=lbl, s = 4))

    plt.legend( tuple(scatters),
                tuple(y_label),
                scatterpoints=1,
                loc='upper right',
                ncol=1, # len(scatters),                                                                                                 
                fontsize=10)
    plt.xlabel('UC 1')
    plt.ylabel('UC 2')
    if Title is not None: 
        plt.title(Title, fontsize=11)
    plt.grid()

# %% [markdown]
# ## 0. 필요한 파일 업로드

# %%
# from google.colab import files
# files.upload()

# %%
# !ls

# %% [markdown]
# ## 1. 분류를 위한 전처리
#
#
# #### (1) 전처리 - csv 파일 불러와서 열기
#
# #### (2) 특징 벡터와 목표값 설정
#
# #### (3) 분류기 정의

# %% [markdown]
# #### 점수 데이터

# %%
###################
## Main function ##
# if __name__ == '__main__':
   
## (1) read data
file_name = 'scores.csv'
df = pd.read_csv(file_name)
print("Data size (n_sample,n_features): ",end='')
print(df.shape)

## (2) Set feature vector and target values
X = df.iloc[:,1:4] 
y = df.Group
label = list(set(y))

print( str(dt.datetime.now().date()) + ", " + str(dt.datetime.now().time()) )
# Out:
# Data size (n_sample,n_features): (100, 4)
# 2020-08-29, 17:28:52.982014

# %% [markdown]
# #### 유전자 발현량 데이터

# %%
#"""
file_name = 'gene_exp.csv'
## read data
df = pd.read_csv(file_name,index_col=0)
print("Data size (n_sample,n_features): ",end='')
print(df.shape)

## Set feature vector and target values
X=np.log(0.01+df.iloc[:,1:]) 
y = df.Tumor_type
label = list(set(y))
print( str(dt.datetime.now().date()) + ", " + str(dt.datetime.now().time()) )
#"""
# Out:
# Data size (n_sample,n_features): (1655, 101)
# 2020-08-29, 17:28:55.413530

# %% [markdown]
# #### 불러온 데이터 를 확인해본다

# %%
X.shape
# Out:
# (1655, 100)

# %% [markdown]
# #### UMAP을 이용한 데이터 확인

# %%
points_2d = TSNE(learning_rate=300, init='pca').fit_transform(X)

draw_scatter( points_2d, y, 'Tumor GEP (UMAP)' )

# %% [markdown]
# #### Heatmap을 이용한 데이터 확인

# %%
lut = dict(zip(set(y), ['r','b','g', 'm', 'c', 'darkviolet', 'coral', 'lime','gold']))
col_colors = y.map(lut)
dfc = pd.DataFrame([col_colors]).transpose()
ax = sb.clustermap(X.transpose(), col_colors = dfc, cmap="mako", figsize = (15,8))

# %% [markdown]
# ## Model: (Binary) Logistic regression model with $l_1$ and $l_2$ penalty
# Source: https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
#
# ### $$ \min_{{\bf w},c} \frac{1-\rho}{2} {\bf w}^T{\bf w} + \rho \| {\bf w} \|_1 + C \sum^{n}_{i=1} \log \left( \exp \left( -y_i \left( {\bf x}^T_i {\bf w} + c \right)  \right) \right) $$
#
# where
#
# 1. $\rho$ controls the relative weight between $l_1$ and $l_2$ penalty. $\rho = 1$ corresponds to LASSO while $\rho=0$ to Ridge.
# 2. $C \rightarrow \infty $ means no penalty.
# 3. In this notation, it’s assumed that the target $y_i$ takes values in the set {+1,-1}.
#
# ## Model: (Multinomial) Logistic regression model with $l_1$ and $l_2$ penalty
#
#
# ### $$ \min_{{\bf \Theta, \theta_0}} \frac{1-\rho}{2} \| {\bf \Theta} \|^2_F + \rho \| {\bf \Theta} \|_1 - C \sum^{n}_{i=1} \log S_{y_i}\left( {\bf \Theta}^T {\bf x}_i + {\bf \theta}_0 \right) $$
# where $S_y(\cdot)$ is soft-max function, ${\bf \Theta}$ is $M \times N$ parameter matrix and ${\rm {\bf \theta_0}}$ is $M \times 1$ intercept vector.
#
# Function description: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %% [markdown]
# (3) Set linear classifier and its parameters to use for regression

# %%
#########################################################
## (3) Set classifier and its parameters to use

classifier = lm.LogisticRegression()
param_default = classifier.get_params()

## set a few parameters for classifier
param = {'penalty': 'l2', 'C': 100, 'multi_class': 'multinomial',
        'solver': 'lbfgs', 'max_iter': 2000 } # , 'fit_intercept': True

## initialize SVM
classifier.set_params(**param)
# Out:
# LogisticRegression(C=100, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=2000,
#                    multi_class='multinomial', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# (3) Alternative: SVM Classifier

# %%
"""
## SVM for classfication
classifier = svm.SVC()
param_default = classifier.get_params()

## set a few parameters for classifier
param = {'kernel': 'linear', 'C': 0.01, 'gamma':'auto' }

## set parameter grid for classifier
param_grid = {'kernel': ['linear','rbf'],
             'C': [0.0001, 0.001, 0.01, 0.1],
             'gamma': ['auto', 'scale']
            }
## initialize SVM
classifier.set_params(**param)
"""
# Out:
# "\n## SVM for classfication\nclassifier = svm.SVC()\nparam_default = classifier.get_params()\n\n## set a few parameters for classifier\nparam = {'kernel': 'linear', 'C': 0.01, 'gamma':'auto' }\n\n## set parameter grid for classifier\nparam_grid = {'kernel': ['linear','rbf'],\n             'C': [0.0001, 0.001, 0.01, 0.1],\n             'gamma': ['auto', 'scale']\n            }\n## initialize SVM\nclassifier.set_params(**param)\n"

# %% [markdown]
# ## 2. 학습 및 평가 절차 (basic)
#
# <div>
# <img src="attachment:train_test.jpg" width="500"/>
# </div>
#
# #### (1) 데이터를 학습데이터와 테스트 데이터로 분리
#
# #### (2) 학습 수행(fit)
#
# #### (3) 테스트 수행 (predict)
#
# #### (4) 성능/결과 확인

# %%
#########################################################
## (1) Claasification example : Naive implementation

## (4) Divide data for traning (70%) and test (30%)
X_train, X_test, y_train, y_test = mod_sel.train_test_split(X, y, test_size=0.3, random_state=5)
## (5) Fit SVM to the data, X_train and y_train
classifier.fit(X_train,y_train)
## (6) Performance test
y_pred = classifier.predict(X_test)
accuracy = 100*sum(y_test==y_pred)/len(y_test)

y_pred_train = classifier.predict(X_train)
accuracy_train = 100*sum(y_train==y_pred_train)/len(y_train)

print( "Accuracy(Naive) = %f, %f" % (round(accuracy,2), round(accuracy_train,2)) )
# Out:
# Accuracy(Naive) = 89.940000, 100.000000

# %% [markdown]
# #### Check soft and hard decision

# %%
## (6) Get class likelihood
y_prob = classifier.predict_proba(X_test)

print('Classes: ', classifier.classes_)
print( 'Original/Predicted label: ', y_test.iloc[0], y_pred[0] )
print( 'Estimated probabilities: ', y_prob[0,:])
# Out:
# Classes:  ['CESC' 'COAD' 'ESCA' 'LUAD' 'PCPG' 'SARC' 'THCA' 'THYM' 'UCEC']
# Original/Predicted label:  CESC CESC
# Estimated probabilities:  [9.99995854e-01 2.94223793e-11 1.51240649e-06 4.74224978e-10
#  3.94688543e-12 3.42864680e-13 1.97960599e-10 4.62987666e-07
#  2.16973832e-06]

# %% [markdown]
# ## 3. 교차 검증을 위한 코드 예제
#
# #### sklearn.model_selection 모듈의 .cross_val_score 사용

# %% [markdown]
# ## L-fold cross-validation (교차 검증)
# 1. We divide the entire data (of N samples) into L groups (of N/L samples per group)
# 2. Select one group for test and use all others for training
# 3. Measure $J \left( \theta^* ; X_{Test}, y_{test} \right)$ and $J \left( \theta^* ; X_{Train}, y_{train} \right)$
# 4. Repeat 2 and 3 for each group and take average on both measures!
# 5. Check if $ J \left( \theta^* ; X_{Test}, y_{test} \right) >> J \left( \theta^* ; X_{Train}, y_{train} \right)$

# %%
#########################################################
## (2) Claasification example: Cross-validation

## Set parameters for cross-validation
NCV = 5
## Performance test
accuracies = mod_sel.cross_val_score(classifier, X, y, scoring='accuracy', cv=NCV, verbose = 2, n_jobs=4)
accuracy = 100*accuracies.mean()
print( "Accuracy(CV) = " + str(round(accuracy,2)) )
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Accuracy(CV) = 90.4
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:    4.9s finished

# %% [markdown]
# #### 평가결과 요약

# %%
## Confusion matrix & performance report
y_pred = mod_sel.cross_val_predict(classifier, X, y, cv=NCV, verbose = 2, n_jobs=4)

c_mat = met.confusion_matrix(y, y_pred)
print("Confusion Matrix: ")
print(c_mat)
print("Classification Report: ")
print(met.classification_report(y, y_pred, target_names=label))
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Confusion Matrix:
# [[159   8  13   0   0   3   0   1  16]
#  [  6 183   7   3   1   0   0   0   0]
#  [ 12  17 146   1   0   4   0   0   2]
#  [  3   5   4 187   1   0   0   0   0]
#  [  0   0   0   0 182   1   0   0   0]
#  [  3   2   5   0   0 185   0   0   5]
#  [  0   0   0   0   0   0 199   0   1]
#  [  1   1   0   1   0   0   0 116   1]
#  [ 24   1   1   1   0   3   1   0 139]]
# Classification Report:
#               precision    recall  f1-score   support
#
#         LUAD       0.76      0.80      0.78       200
#         PCPG       0.84      0.92      0.88       200
#         CESC       0.83      0.80      0.82       182
#         ESCA       0.97      0.94      0.95       200
#         COAD       0.99      0.99      0.99       183
#         THCA       0.94      0.93      0.93       200
#         THYM       0.99      0.99      0.99       200
#         UCEC       0.99      0.97      0.98       120
# ...

# %% [markdown]
#  ## 4 학습을 통해 획득한 최적 파라미터 확인

# %%
print( "theta_0 (intercept) = " + str(classifier.intercept_) )
print( "theta[1:M] = " )
print( str(classifier.coef_.transpose()) )
# Out:
# theta_0 (intercept) = [-15.4393084   -6.33035325   7.33408586  -1.86997926   3.98441973
#    2.55768609   3.23624923   7.76899522  -1.24179522]
# theta[1:M] =
# [[-3.90471926e-01 -2.98407736e-01  1.14345399e-01 -2.70866955e-01
#   -1.64685313e-01 -5.70035666e-02 -3.96586947e-02  4.23200115e-01
#    6.83548678e-01]
#  [-6.69979423e-01  3.21697748e-01 -1.04046434e-01  2.36483260e-01
#   -1.22880880e-01  1.58576169e-01  4.80527377e-02  4.77904084e-01
#   -3.45807263e-01]
#  [ 1.98956332e-02  2.85869042e-02 -8.28782347e-01 -2.21888905e-01
#    1.28929405e-01  4.55697773e-01  4.80261572e-02  4.51451833e-01
#   -8.19164535e-02]
#  [ 7.55572472e-02 -1.21240114e-01  3.88160278e-02 -2.88297244e-01
#   -3.16653182e-01  2.28801808e-01 -1.33443193e-01  4.81462510e-01
#    3.49961407e-02]
#  [-2.92607841e-01  3.41533700e-01 -3.15589369e-01 -1.00844964e-01
#   -1.83567115e-01 -4.84573955e-01 -8.47727071e-02  3.13721893e-01
#    8.06700358e-01]
# ...

# %% [markdown]
# ## 5. 그리드 탐색을 이용한 하이퍼 파라미터 최적화
#
# #### (1) 파라미터 그리드 설정
#
# #### (2) sklearn.model_selection 모듈의 .GridSearchCV 사용
#
# #### (3) 베스트 파라미터 추출
#
# #### (4) 베스트 파라미터를 이용한 성능 (재) 평가

# %%
#########################################################
## (3) Claasification example Using SVM: Parameter Optimization (grid search)

## Set parameters for cross-validation
NCV = 5

## (4) set parameter grid for classifier
param_grid = {'penalty': ['l2'],
             'C': [10, 100, 1000],
             'multi_class': ['multinomial'],
             'solver': ['lbfgs'],
             'max_iter': [2000],
            }

## (5) Search grid to find best parameters
clf = mod_sel.GridSearchCV(classifier, param_grid, cv=NCV, scoring='accuracy', verbose = 2, n_jobs=4)
clf.fit(X,y)

## (6) Get best paramter
best_param = clf.best_params_
print("Best Scroe: " + str(round(clf.best_score_*100,2)) + " with parameters ", end='' )
print(clf.best_params_)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  15 out of  15 | elapsed:    6.7s finished
# Best Scroe: 90.63 with parameters {'C': 10, 'max_iter': 2000, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}

# %% [markdown]
# ## Homework
#
# 데이터 시각화에서 다루었던 IRIS 데이터와 8x8의 숫자 이미지 데이터에 대해 위 과정을 수행하고 그 결과를 보고서로 작성하여 제출하라.이 때 다음의 절차에 나오는 키워드들을 고려하여 보고서를 작성하라.

# %% [markdown]
# ## Design steps for beginner
# 1. Choose a function you want to implement (input/output formats are pre-defined)
# 2. Search for some open SW packages to choose/construct an appropriate model $f(\cdot ; {\bf \theta})$ and try to modify slightly
# 3. Download dataset ${\bf X,y}$ from the internet
# 4. Use the packages to train the model to get ${\bf \theta^*}$
# 5. Use $f(\cdot ; {\bf \theta^*})$ to evaluate the performance
# 6. If satisfied, you are done! Otherwise, go to step 2 (skip 3).
